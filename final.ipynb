# %% [markdown]
# # Proyecto MD - Predictor de personas con autismo

# %% [markdown]
# # Indice

# %% [markdown]
# 1. Introducción
# 1.1 Análisis de variables
# 2. Pipeline
# 2.1 Componentes
# 2.2 Métricas de validación y evaluación
# 3. Experimentos
# 3.1 Análisis del componente de Detector de Outliers
# 3.2 Análisis del componente de Estandarizador
# 4. Conclusiones

# %% [markdown]
# # 1. Introducción

# %% [markdown]
# El problema que hemos elegido para nuestro proyecto es la predicción de que una persona tenga autismo, y los datos
# utilizados para ello estan almacenados en el dataset "Autism-Adult-Data.csv".
#
# Para poder resolverlo, primero analizaremos bien nuestro problema, posteriormente crearemos el mejor sistema de predicción,
# y finalmente reflexionaremos sobre que tan buena es la solución que hemos obtenido.
#
# A continuación, mostramos el ánalisis previo de las variables de nuestro dataset.

# %% [markdown]
# ## 1.1 Analisis de variables

# %% [markdown]
# # 2. Pipeline

# %% [markdown]
# ## 2.1 Componentes

# %% [markdown]
# Ponemos las clases de los componentes

# %% [markdown]
# ## 2.2 Métricas de validación y evaluación

# %% [markdown]
# Explicamos la metrica de validación y evaluación

# %% [markdown]
# # 3. Experimentos

# %% [markdown]
# Contamos lo que vamos a hacer, podemos mostrar la pipeline base desde la que partiremos en los experimentos

# %% [markdown]
# ## 3.1 Análisis del modelo base
#
# Analizamos como el modelo base se comporta en rendimiento para luego comparar este resultado con los próximos análisis.

# %% [markdown]
# ## 3.2 Análisis del componente DetectorOutlier

# %% [markdown]
# Analizamos como el componente influye en los resultados del modelo base (Base + DetectorOutlier)

# %% [markdown]
# ## 3.3 Análisis del componente Estandarizador

# %% [markdown]
# Analizamos como el componente influye en los resultados del modelo base (Base + Estandarizador)

# %% [markdown]
# ## 3.4 Mejor pipeline

# %% [markdown]
# Mostramos la mejor pipleline obtenida para nuestro problema

# %% [markdown]
# # 4. Conclusiones

# %% [markdown]
# Reflexionamos sobre si el mejor modelo obtenido es suficiente para nuestro problema
