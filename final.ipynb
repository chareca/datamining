# %% [markdown]
# # 1. Introducción

# %% [markdown]
# Explicamos el problema a resolver ...

# %% [markdown]
# ## 1.1 Analisis de variables

# %% [markdown]
# # 2. Pipeline

# %% [markdown]
# ## 2.1 Componentes

# %% [markdown]
# Ponemos las clases de los componentes

# %% [markdown]
# ## 2.2 Métricas de validación y evaluación

# %% [markdown]
# Explicamos la metrica de validación y evaluación

# %% [markdown]
# # 3. Experimentos

# %% [markdown]
# Contamos lo que vamos a hacer, podemos mostrar la pipeline base desde la que partiremos en los experimentos

# %% [markdown]
# ## 3.1 Análisis del componente DetectorOutlier

# %% [markdown]
# Analizamos como el componente DetectorOutlier influye en el pipeline base.

# %% [markdown]
# ## 3.2 Análisis del componente Estandarizador

# %% [markdown]
# Analizamos como el componente influye en los resultados anteriores (Base + DetectorOutlier)

# %% [markdown]
# ## 3.3 Mejor pipeline

# %% [markdown]
# Mostramos la mejor pipleline obtenida para nuestro problema

# %% [markdown]
# # 4. Conclusiones
